# %% [markdown]
# # AutoRegressive Model (AR)

# %%
from PIL import Image
Image.open('AR.png')

# using past values to predict (basically using multiple linear regression processes)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1017x298 at 0x7F692C08E208>

# %% [markdown]
# # Moving Average (MA)

# %%
Image.open('MA.png')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=968x323 at 0x7F691D0FB710>
